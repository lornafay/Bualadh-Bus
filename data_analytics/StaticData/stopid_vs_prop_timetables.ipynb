# %% [markdown]
# # Static tables: "Monday", "Tuesday"...."Sunday"
# # Stop ID schedule and trip proportion for each route ID
#
# In order to obtain a travel time prediction for a user's selected journey segment, we implement a machine learning-based algorithm which first predicts the total trip time for that route given the environmental conditions, and secondly obtain the proportion of the user's chosen segment of that total route. This notebook outlines the steps taken to compile a static table containing, for each bus route ID, the list of stops and their respective proportion from the start of the bus trip up to that stop in the one direction (route ID mirrors direction). Therefore, this table must be queried to reflect the user's chosen start and end point. The user's embarking stop proportion is subtracted from that of the disembarking stop to obtain the total segment proportion.<br><br>
# &emsp;For each stop served by a given route, we also document the list of scheduled departure times for the route on that day. This allows us to build a timetable feature later on as an add-on to our application, without the need for a static table for that task alone.

# %%
#Import package pandas for data analysis
import pandas as pd
# Import package numpy for numeric computing
import numpy as np
from numpy import int64
from numpy import float64
from numpy import datetime64
# Import package matplotlib for visualisation/plotting
import matplotlib.pyplot as plt
import matplotlib.dates as dates
# Allows plots to appear directly in the notebook.
# %matplotlib inline
# For dealing with some Accented characters (in Irish Place names)
import unidecode
# Date/time functionality
import datetime
import time
# Check if files exist
from os.path import exists
from os import makedirs
# System specific parameters and functions
import sys
# look at some z-scores for inspecting outliers.
from scipy import stats
import seaborn as sb
# lookup lat/long and convert lat/long to national grid references.
#import geopy
#import pyproj

from patsy import dmatrices
from sklearn import metrics

from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
#from sklearn.tree import export_text

from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import train_test_split

#import graphviz
#from graphviz import Source
#to read all CSV files in a folder
import os
import glob


# prevent columns being hidden
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
#method to read chunks from a file and create a dataframe list.
def get_chunks(x):
    """x=[location, dtypes, datecolumns ,date_parser_func, cols]
    exp:mydateparser = lambda x: pd.to_datetime(x, format="%Y-%m-%d %H:%M:%S")
    exp:dtypes={'TRIPID' :'category','PROGRNUMBER':'int16','STOPPOINTID':'category','PLANNEDTIME_ARR':'int64','PLANNEDTIME_DEP':'int64','ACTUALTIME_ARR':'int64','ACTUALTIME_DEP':'int64','DIFFERENCETIME_ARR':'int64','DIFFERENCETIME_DEP':'int64','LINEID':'category','ROUTEID':'category','DIRECTION':'category','TRIPS_TIME_PROPORTION':'float32','TOTAL_JOURNEY_TIME':'int16','TIME_OF_DAY':'category','DAY_OF_WEEK':'category'}
    exp:cols=['Date time','Temperature','Wind Speed','Precipitation','Cloud Cover']
    exp:x=['/Chunks/DBUS/QP_Implementation',dtypes,['ACTUALTIME_ARR_DATETIME'],mydateparser, cols]"""
    cwd=os.getcwd()
    path = x[0]
    chunk_folder = glob.glob(os.path.join(path, "*.csv"))
    chunk_list=[]
    counter=0
    for filename in chunk_folder:
        # read the csv file
        if len(x)==4:
            df_chunk = pd.read_csv(filename, low_memory=False, dtype=x[1],parse_dates=x[2],date_parser=x[3])
        else:
            df_chunk = pd.read_csv(filename, usecols=x[4], low_memory=False, dtype=x[1],parse_dates=x[2],date_parser=x[3])
        chunk_list.append(df_chunk)
        print('Index at chunk_list',counter,' is ', filename, ': ',df_chunk.shape)
        counter+=1
    return chunk_list

#chunk_dbus_list=get_chunks(arg_list)

# %%
# get the timetable files
def getTimetableChunks(x):
    """x=[location, dtypes, datecolumns ,date_parser_func, cols]
    exp:mydateparser = lambda x: pd.to_datetime(x, format="%Y-%m-%d %H:%M:%S")
    exp:dtypes={'TRIPID' :'category','PROGRNUMBER':'int16','STOPPOINTID':'category','PLANNEDTIME_ARR':'int64','PLANNEDTIME_DEP':'int64','ACTUALTIME_ARR':'int64','ACTUALTIME_DEP':'int64','DIFFERENCETIME_ARR':'int64','DIFFERENCETIME_DEP':'int64','LINEID':'category','ROUTEID':'category','DIRECTION':'category','TRIPS_TIME_PROPORTION':'float32','TOTAL_JOURNEY_TIME':'int16','TIME_OF_DAY':'category','DAY_OF_WEEK':'category'}
    exp:cols=['Date time','Temperature','Wind Speed','Precipitation','Cloud Cover']
    exp:x=['/Chunks/DBUS/QP_Implementation',dtypes,['ACTUALTIME_ARR_DATETIME'],mydateparser, cols]"""
    cwd=os.getcwd()
    path = x[0]
    chunk_folder = glob.glob(os.path.join(path, "*.csv"))
    chunk_list=[]
    counter=0
    for filename in chunk_folder:
        # read the csv file
        df_chunk = pd.read_csv(filename, low_memory=False, dtype=x[1], index_col=0)
        chunk_list.append(df_chunk)
        print('Index at chunk_list',counter,' is ', filename, ': ',df_chunk.shape)
        counter+=1
    return chunk_list

# %%
def getDayTimetable(df, day):
    """Creates a timetable for a given weekday on a given route dataframe."""
    df = df[df.DAY_OF_WEEK == day]
    df_max_PROGRNUMBER=pd.DataFrame(df.groupby(['TRIPID'])['PROGRNUMBER'].max())
    df_max_PROGRNUMBER.rename(columns={'PROGRNUMBER':'PROGRNUMBER_MAX'},inplace=True)
    df = pd.merge(df, df_max_PROGRNUMBER, on="TRIPID", how="left")
    max_PROGRNUMBER = np.amax(df['PROGRNUMBER'].unique())
    df.drop(df[df.PROGRNUMBER_MAX != max_PROGRNUMBER].index, inplace=True)
    target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
    target.dropna(how='any', inplace=True)
    this_route = target['ROUTEID'].unique()[0]
    # convert planned dep time to int
    target = target.astype({'PLANNEDTIME_DEP':'int32'})
    
    # write to new csv in timetable folder
    target.to_csv(f'../timetables_V3/{this_route}_{day}.csv')

# %% [markdown]
# ## 1 Read Chunks
#
# Each route's dataset is found in the IMP_ROUTE_ID folder, which contains routes that operated throughout the year (temporary routes filtered out as outliers). Hourly weather data also imported in this file.

# %%
dtype={'TRIPID' :'category',
       'PROGRNUMBER':'int16',
       'STOPPOINTID':'category',
       'PLANNEDTIME_ARR':'int64',
       'PLANNEDTIME_DEP':'int64',
       'ACTUALTIME_ARR':'int64',
       'ACTUALTIME_DEP':'int64',
       'DIFFERENCETIME_ARR':'int64',
       'DIFFERENCETIME_DEP':'int64',
       'ROUTEID':'category',
       'TOTAL_JOURNEY_TIME':'int16',
       'TIME_OF_DAY':'category',
       'DAY_OF_WEEK':'category',
       'TRIPS_TIME_PROPORTION_v2':'float32',
       'PLANNEDTIME_DEP_R_M5':'category',
       'rain':'float16',
       'temp':'float16',
       'wet_bulb_temp(C)':'float16',
       'dew_pt_temp(C)':'float16',
       'vapour_pressure(hPa)':'float16',
       'humidity(%)':'int16',
       'sea_lvl_pressure(hPa)':'float16'}

mydateparser = lambda x: pd.to_datetime(x, format="%Y-%m-%d %H:%M:%S")


data_list = ["../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/", dtype, ['ACTUALTIME_ARR_DATETIME'], mydateparser]

# %%
chunks = get_chunks(data_list)
# Out:
# Index at chunk_list 0  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/18_3.csv :  (826557, 25)
# Index at chunk_list 1  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/67_6.csv :  (775062, 25)
# Index at chunk_list 2  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/142_9.csv :  (23881, 25)
# Index at chunk_list 3  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17_16.csv :  (29666, 25)
# Index at chunk_list 4  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/46A_74.csv :  (2094278, 25)
# Index at chunk_list 5  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/122_14.csv :  (427306, 25)
# Index at chunk_list 6  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/150_8.csv :  (524122, 25)
# Index at chunk_list 7  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33X_49.csv :  (56923, 25)
# Index at chunk_list 8  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83_19.csv :  (96394, 25)
# Index at chunk_list 9  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/270_44.csv :  (100767, 25)
# Index at chunk_list 10  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84_30.csv :  (359700, 25)
# Index at chunk_list 11  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/130_10.csv :  (997446, 25)
# Index at chunk_list 12  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66A_36.csv :  (85098, 25)
# Index at chunk_list 13  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/46A_66.csv :  (44682, 25)
# Index at chunk_list 14  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/102_8.csv :  (486179, 25)
# Index at chunk_list 15  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_81.csv :  (226074, 25)
# Index at chunk_list 16  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66_11.csv :  (252443, 25)
# Index at chunk_list 17  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/26_28.csv :  (131001, 25)
# Index at chunk_list 18  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/104_15.csv :  (130509, 25)
# Index at chunk_list 19  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40_31.csv :  (2216469, 25)
# Index at chunk_list 20  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15_19.csv :  (375915, 25)
# Index at chunk_list 21  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/145_106.csv :  (42056, 25)
# Index at chunk_list 22  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/76_37.csv :  (396068, 25)
# Index at chunk_list 23  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_57.csv :  (10593, 25)
# Index at chunk_list 24  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/67_4.csv :  (795613, 25)
# Index at chunk_list 25  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_68.csv :  (563968, 25)
# Index at chunk_list 26  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38_9.csv :  (476258, 25)
# Index at chunk_list 27  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_79.csv :  (50986, 25)
# Index at chunk_list 28  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/120_13.csv :  (69999, 25)
# Index at chunk_list 29  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83_25.csv :  (88895, 25)
# Index at chunk_list 30  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/16_21.csv :  (112324, 25)
# Index at chunk_list 31  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/65_74.csv :  (178623, 25)
# Index at chunk_list 32  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38A_32.csv :  (367325, 25)
# Index at chunk_list 33  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40B_65.csv :  (74284, 25)
# Index at chunk_list 34  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/4_10.csv :  (995087, 25)
# Index at chunk_list 35  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/16C_28.csv :  (27325, 25)
# Index at chunk_list 36  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84A_3.csv :  (54410, 25)
# Index at chunk_list 37  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15B_64.csv :  (190587, 25)
# Index at chunk_list 38  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/77A_29.csv :  (930359, 25)
# Index at chunk_list 39  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/44_40.csv :  (439568, 25)
# Index at chunk_list 40  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/47_138.csv :  (51263, 25)
# Index at chunk_list 41  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40D_102.csv :  (368973, 25)
# Index at chunk_list 42  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83_16.csv :  (980052, 25)
# Index at chunk_list 43  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_59.csv :  (4592, 25)
# Index at chunk_list 44  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/79_11.csv :  (344741, 25)
# Index at chunk_list 45  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/1_41.csv :  (46623, 25)
# Index at chunk_list 46  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/65_75.csv :  (143137, 25)
# Index at chunk_list 47  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/39A_40.csv :  (1819553, 25)
# Index at chunk_list 48  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/29A_15.csv :  (760115, 25)
# Index at chunk_list 49  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7_70.csv :  (372284, 25)
# Index at chunk_list 50  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/184_28.csv :  (339355, 25)
# Index at chunk_list 51  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/140_19.csv :  (943737, 25)
# Index at chunk_list 52  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40E_90.csv :  (16834, 25)
# Index at chunk_list 53  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38_10.csv :  (86434, 25)
# Index at chunk_list 54  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/46A_67.csv :  (2106213, 25)
# Index at chunk_list 55  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83A_26.csv :  (45702, 25)
# Index at chunk_list 56  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17_15.csv :  (524060, 25)
# Index at chunk_list 57  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/1_38.csv :  (45811, 25)
# Index at chunk_list 58  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27B_23.csv :  (637180, 25)
# Index at chunk_list 59  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_72.csv :  (78109, 25)
# Index at chunk_list 60  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27B_40.csv :  (42530, 25)
# Index at chunk_list 61  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83A_17.csv :  (247136, 25)
# Index at chunk_list 62  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33_45.csv :  (295091, 25)
# Index at chunk_list 63  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15_17.csv :  (1943109, 25)
# Index at chunk_list 64  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/123_36.csv :  (1085866, 25)
# Index at chunk_list 65  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40D_101.csv :  (194227, 25)
# Index at chunk_list 66  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/14_15.csv :  (1354863, 25)
# Index at chunk_list 67  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/111_8.csv :  (133649, 25)
# Index at chunk_list 68  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84A_1.csv :  (54736, 25)
# Index at chunk_list 69  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/54A_12.csv :  (398834, 25)
# Index at chunk_list 70  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/65_77.csv :  (205531, 25)
# Index at chunk_list 71  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/75_21.csv :  (75561, 25)
# Index at chunk_list 72  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66B_55.csv :  (98266, 25)
# Index at chunk_list 73  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/4_14.csv :  (136436, 25)
# Index at chunk_list 74  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/9_7.csv :  (1391972, 25)
# Index at chunk_list 75  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/79A_28.csv :  (266196, 25)
# Index at chunk_list 76  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/75_18.csv :  (86250, 25)
# Index at chunk_list 77  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/142_12.csv :  (46872, 25)
# Index at chunk_list 78  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_17.csv :  (587575, 25)
# Index at chunk_list 79  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/14_16.csv :  (1290699, 25)
# Index at chunk_list 80  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15A_83.csv :  (614112, 25)
# Index at chunk_list 81  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/39_21.csv :  (971904, 25)
# Index at chunk_list 82  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/151_18.csv :  (110262, 25)
# Index at chunk_list 83  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/238_15.csv :  (111480, 25)
# Index at chunk_list 84  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/79A_27.csv :  (291914, 25)
# Index at chunk_list 85  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7_73.csv :  (135923, 25)
# Index at chunk_list 86  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/69_47.csv :  (214862, 25)
# Index at chunk_list 87  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_66.csv :  (114180, 25)
# Index at chunk_list 88  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/32_58.csv :  (448425, 25)
# Index at chunk_list 89  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/145_91.csv :  (77747, 25)
# Index at chunk_list 90  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66_13.csv :  (223485, 25)
# Index at chunk_list 91  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_56.csv :  (63446, 25)
# Index at chunk_list 92  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/14_12.csv :  (24388, 25)
# Index at chunk_list 93  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83A_23.csv :  (256801, 25)
# Index at chunk_list 94  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/53_20.csv :  (73975, 25)
# Index at chunk_list 95  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/11_40.csv :  (525669, 25)
# Index at chunk_list 96  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83_22.csv :  (922898, 25)
# Index at chunk_list 97  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/151_16.csv :  (157604, 25)
# Index at chunk_list 98  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84_31.csv :  (124943, 25)
# Index at chunk_list 99  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66A_37.csv :  (150587, 25)
# Index at chunk_list 100  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/150_10.csv :  (59252, 25)
# Index at chunk_list 101  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/122_16.csv :  (443031, 25)
# Index at chunk_list 102  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/239_28.csv :  (100386, 25)
# Index at chunk_list 103  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38A_20.csv :  (384724, 25)
# Index at chunk_list 104  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40D_104.csv :  (350989, 25)
# Index at chunk_list 105  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/53_21.csv :  (74765, 25)
# Index at chunk_list 106  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/102_9.csv :  (478863, 25)
# Index at chunk_list 107  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38B_40.csv :  (58460, 25)
# Index at chunk_list 108  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_60.csv :  (4953, 25)
# Index at chunk_list 109  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/26_29.csv :  (115602, 25)
# Index at chunk_list 110  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/114_6.csv :  (141552, 25)
# Index at chunk_list 111  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84X_62.csv :  (45909, 25)
# Index at chunk_list 112  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7A_86.csv :  (180619, 25)
# Index at chunk_list 113  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/270_42.csv :  (95202, 25)
# Index at chunk_list 114  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7A_89.csv :  (90863, 25)
# Index at chunk_list 115  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/111_7.csv :  (178931, 25)
# Index at chunk_list 116  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_50.csv :  (31278, 25)
# Index at chunk_list 117  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/26_24.csv :  (80338, 25)
# Index at chunk_list 118  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40_32.csv :  (29196, 25)
# Index at chunk_list 119  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84_28.csv :  (113993, 25)
# Index at chunk_list 120  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_11.csv :  (185257, 25)
# Index at chunk_list 121  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7_74.csv :  (79775, 25)
# Index at chunk_list 122  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38B_44.csv :  (73062, 25)
# Index at chunk_list 123  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27_19.csv :  (2031631, 25)
# Index at chunk_list 124  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84_27.csv :  (362780, 25)
# Index at chunk_list 125  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7_66.csv :  (83321, 25)
# Index at chunk_list 126  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15B_61.csv :  (639913, 25)
# Index at chunk_list 127  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/142_8.csv :  (26876, 25)
# Index at chunk_list 128  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27B_34.csv :  (523030, 25)
# Index at chunk_list 129  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/70_67.csv :  (329967, 25)
# Index at chunk_list 130  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/44B_61.csv :  (29343, 25)
# Index at chunk_list 131  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/45A_64.csv :  (319843, 25)
# Index at chunk_list 132  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41C_83.csv :  (56605, 25)
# Index at chunk_list 133  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/161_51.csv :  (15694, 25)
# Index at chunk_list 134  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33X_46.csv :  (62659, 25)
# Index at chunk_list 135  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38_15.csv :  (52953, 25)
# Index at chunk_list 136  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_80.csv :  (61004, 25)
# Index at chunk_list 137  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41B_52.csv :  (65858, 25)
# Index at chunk_list 138  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_73.csv :  (55435, 25)
# Index at chunk_list 139  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/184_29.csv :  (336262, 25)
# Index at chunk_list 140  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/140_21.csv :  (903010, 25)
# Index at chunk_list 141  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25B_274.csv :  (555506, 25)
# Index at chunk_list 142  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/220_10.csv :  (208084, 25)
# Index at chunk_list 143  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15_18.csv :  (31950, 25)
# Index at chunk_list 144  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/31_18.csv :  (634009, 25)
# Index at chunk_list 145  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/39A_43.csv :  (1880475, 25)
# Index at chunk_list 146  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/56A_30.csv :  (259252, 25)
# Index at chunk_list 147  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33B_56.csv :  (142479, 25)
# Index at chunk_list 148  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66B_57.csv :  (85059, 25)
# Index at chunk_list 149  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/239_26.csv :  (105100, 25)
# Index at chunk_list 150  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_65.csv :  (131825, 25)
# Index at chunk_list 151  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/84X_57.csv :  (40425, 25)
# Index at chunk_list 152  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/54A_11.csv :  (407360, 25)
# Index at chunk_list 153  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/47_139.csv :  (263370, 25)
# Index at chunk_list 154  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41C_84.csv :  (56880, 25)
# Index at chunk_list 155  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_53.csv :  (40228, 25)
# Index at chunk_list 156  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/9_5.csv :  (1342497, 25)
# Index at chunk_list 157  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/4_12.csv :  (924507, 25)
# Index at chunk_list 158  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27B_36.csv :  (36357, 25)
# Index at chunk_list 159  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/1_40.csv :  (638906, 25)
# Index at chunk_list 160  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/69_44.csv :  (153083, 25)
# Index at chunk_list 161  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/26_26.csv :  (70790, 25)
# Index at chunk_list 162  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/59_11.csv :  (113563, 25)
# Index at chunk_list 163  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/120_7.csv :  (316702, 25)
# Index at chunk_list 164  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/151_17.csv :  (692663, 25)
# Index at chunk_list 165  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/70_60.csv :  (326793, 25)
# Index at chunk_list 166  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27B_35.csv :  (138812, 25)
# Index at chunk_list 167  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25A_270.csv :  (572170, 25)
# Index at chunk_list 168  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/32_57.csv :  (421092, 25)
# Index at chunk_list 169  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41B_53.csv :  (58874, 25)
# Index at chunk_list 170  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/53_23.csv :  (5724, 25)
# Index at chunk_list 171  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/44_36.csv :  (448610, 25)
# Index at chunk_list 172  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/61_106.csv :  (246711, 25)
# Index at chunk_list 173  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41C_78.csv :  (740820, 25)
# Index at chunk_list 174  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/65B_66.csv :  (347417, 25)
# Index at chunk_list 175  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/49_27.csv :  (475452, 25)
# Index at chunk_list 176  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38_14.csv :  (527184, 25)
# Index at chunk_list 177  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/18_4.csv :  (783294, 25)
# Index at chunk_list 178  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/39A_42.csv :  (32949, 25)
# Index at chunk_list 179  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/61_108.csv :  (254589, 25)
# Index at chunk_list 180  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/102_10.csv :  (32176, 25)
# Index at chunk_list 181  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_85.csv :  (73323, 25)
# Index at chunk_list 182  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/63_28.csv :  (68242, 25)
# Index at chunk_list 183  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/11_42.csv :  (852252, 25)
# Index at chunk_list 184  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/29A_14.csv :  (692725, 25)
# Index at chunk_list 185  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_12.csv :  (34244, 25)
# Index at chunk_list 186  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15B_60.csv :  (804882, 25)
# Index at chunk_list 187  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/79_10.csv :  (359176, 25)
# Index at chunk_list 188  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15A_84.csv :  (501677, 25)
# Index at chunk_list 189  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/16_20.csv :  (1533552, 25)
# Index at chunk_list 190  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/31A_25.csv :  (215339, 25)
# Index at chunk_list 191  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/65_72.csv :  (140796, 25)
# Index at chunk_list 192  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33B_58.csv :  (166054, 25)
# Index at chunk_list 193  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41_7.csv :  (808766, 25)
# Index at chunk_list 194  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7A_87.csv :  (398065, 25)
# Index at chunk_list 195  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_70.csv :  (125064, 25)
# Index at chunk_list 196  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/39_23.csv :  (42273, 25)
# Index at chunk_list 197  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/161_50.csv :  (19082, 25)
# Index at chunk_list 198  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/65B_65.csv :  (385296, 25)
# Index at chunk_list 199  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40B_63.csv :  (61537, 25)
# Index at chunk_list 200  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_84.csv :  (61262, 25)
# Index at chunk_list 201  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7_72.csv :  (415455, 25)
# Index at chunk_list 202  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/43_84.csv :  (394968, 25)
# Index at chunk_list 203  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/69_43.csv :  (134787, 25)
# Index at chunk_list 204  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41_3.csv :  (707418, 25)
# Index at chunk_list 205  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/75_19.csv :  (665283, 25)
# Index at chunk_list 206  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27_17.csv :  (1074978, 25)
# Index at chunk_list 207  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33A_25.csv :  (97788, 25)
# Index at chunk_list 208  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/47_135.csv :  (63728, 25)
# Index at chunk_list 209  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/76_36.csv :  (390384, 25)
# Index at chunk_list 210  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25_269.csv :  (214495, 25)
# Index at chunk_list 211  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/150_9.csv :  (513105, 25)
# Index at chunk_list 212  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/220_12.csv :  (216987, 25)
# Index at chunk_list 213  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/67X_46.csv :  (54237, 25)
# Index at chunk_list 214  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/130_11.csv :  (1014362, 25)
# Index at chunk_list 215  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33A_22.csv :  (95132, 25)
# Index at chunk_list 216  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/122_18.csv :  (473818, 25)
# Index at chunk_list 217  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7B_91.csv :  (49922, 25)
# Index at chunk_list 218  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_78.csv :  (65105, 25)
# Index at chunk_list 219  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66A_34.csv :  (92192, 25)
# Index at chunk_list 220  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27_12.csv :  (52888, 25)
# Index at chunk_list 221  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7A_85.csv :  (526150, 25)
# Index at chunk_list 222  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33_70.csv :  (410226, 25)
# Index at chunk_list 223  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/238_11.csv :  (98449, 25)
# Index at chunk_list 224  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/63_25.csv :  (73410, 25)
# Index at chunk_list 225  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/104_16.csv :  (135076, 25)
# Index at chunk_list 226  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/69_45.csv :  (176777, 25)
# Index at chunk_list 227  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41_22.csv :  (51534, 25)
# Index at chunk_list 228  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_15.csv :  (590993, 25)
# Index at chunk_list 229  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_51.csv :  (8122, 25)
# Index at chunk_list 230  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_66.csv :  (30610, 25)
# Index at chunk_list 231  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_52.csv :  (6274, 25)
# Index at chunk_list 232  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/123_34.csv :  (1003741, 25)
# Index at chunk_list 233  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25D_275.csv :  (28606, 25)
# Index at chunk_list 234  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/120_9.csv :  (300797, 25)
# Index at chunk_list 235  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/42_42.csv :  (653028, 25)
# Index at chunk_list 236  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/68_83.csv :  (227252, 25)
# Index at chunk_list 237  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40_27.csv :  (2083206, 25)
# Index at chunk_list 238  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/42_44.csv :  (730279, 25)
# Index at chunk_list 239  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33_44.csv :  (416162, 25)
# Index at chunk_list 240  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25B_271.csv :  (537882, 25)
# Index at chunk_list 241  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/151_15.csv :  (599291, 25)
# Index at chunk_list 242  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_13.csv :  (178207, 25)
# Index at chunk_list 243  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27_9.csv :  (53990, 25)
# Index at chunk_list 244  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25A_273.csv :  (560709, 25)
# Index at chunk_list 245  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17_11.csv :  (29379, 25)
# Index at chunk_list 246  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_18.csv :  (67955, 25)
# Index at chunk_list 247  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_63.csv :  (149993, 25)
# Index at chunk_list 248  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66B_59.csv :  (139636, 25)
# Index at chunk_list 249  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/37_15.csv :  (963643, 25)
# Index at chunk_list 250  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/145_105.csv :  (1926278, 25)
# Index at chunk_list 251  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/16_24.csv :  (1656536, 25)
# Index at chunk_list 252  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_16.csv :  (79123, 25)
# Index at chunk_list 253  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/33_72.csv :  (304625, 25)
# Index at chunk_list 254  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/38A_33.csv :  (62279, 25)
# Index at chunk_list 255  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15_16.csv :  (1532473, 25)
# Index at chunk_list 256  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7B_93.csv :  (70065, 25)
# Index at chunk_list 257  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27A_4.csv :  (378802, 25)
# Index at chunk_list 258  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/59_10.csv :  (99918, 25)
# Index at chunk_list 259  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/75_17.csv :  (622089, 25)
# Index at chunk_list 260  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/44B_60.csv :  (32940, 25)
# Index at chunk_list 261  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_67.csv :  (767187, 25)
# Index at chunk_list 262  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66_17.csv :  (403689, 25)
# Index at chunk_list 263  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/31_15.csv :  (595586, 25)
# Index at chunk_list 264  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/31A_26.csv :  (217823, 25)
# Index at chunk_list 265  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25D_277.csv :  (24270, 25)
# Index at chunk_list 266  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/43_88.csv :  (371292, 25)
# Index at chunk_list 267  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/145_102.csv :  (1954206, 25)
# Index at chunk_list 268  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/77A_28.csv :  (920624, 25)
# Index at chunk_list 269  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40E_91.csv :  (16571, 25)
# Index at chunk_list 270  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_61.csv :  (596998, 25)
# Index at chunk_list 271  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7A_88.csv :  (244252, 25)
# Index at chunk_list 272  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41C_80.csv :  (83622, 25)
# Index at chunk_list 273  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/185_55.csv :  (9807, 25)
# Index at chunk_list 274  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/27A_5.csv :  (371655, 25)
# Index at chunk_list 275  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/39X_1.csv :  (24241, 25)
# Index at chunk_list 276  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/37_14.csv :  (927329, 25)
# Index at chunk_list 277  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/56A_31.csv :  (273176, 25)
# Index at chunk_list 278  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/25_272.csv :  (206191, 25)
# Index at chunk_list 279  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/49_28.csv :  (501118, 25)
# Index at chunk_list 280  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/63_30.csv :  (195912, 25)
# Index at chunk_list 281  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/45A_70.csv :  (136336, 25)
# Index at chunk_list 282  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/1_37.csv :  (596367, 25)
# Index at chunk_list 283  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/114_5.csv :  (139632, 25)
# Index at chunk_list 284  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/77A_30.csv :  (209523, 25)
# Index at chunk_list 285  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/45A_60.csv :  (332975, 25)
# Index at chunk_list 286  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/111_9.csv :  (32048, 25)
# Index at chunk_list 287  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/122_20.csv :  (480129, 25)
# Index at chunk_list 288  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66_18.csv :  (361709, 25)
# Index at chunk_list 289  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/45A_68.csv :  (93401, 25)
# Index at chunk_list 290  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/13_60.csv :  (638689, 25)
# Index at chunk_list 291  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/77A_31.csv :  (206682, 25)
# Index at chunk_list 292  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/120_12.csv :  (75605, 25)
# Index at chunk_list 293  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/7_71.csv :  (193075, 25)
# Index at chunk_list 294  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/41C_79.csv :  (651371, 25)
# Index at chunk_list 295  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/83A_20.csv :  (48092, 25)
# Index at chunk_list 296  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/39_20.csv :  (802676, 25)
# Index at chunk_list 297  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/63_26.csv :  (230720, 25)
# Index at chunk_list 298  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66B_58.csv :  (161625, 25)
# Index at chunk_list 299  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17_10.csv :  (508784, 25)
# Index at chunk_list 300  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/17A_14.csv :  (33313, 25)
# Index at chunk_list 301  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/66A_38.csv :  (140232, 25)
# Index at chunk_list 302  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/15A_85.csv :  (116290, 25)
# Index at chunk_list 303  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/47_136.csv :  (259213, 25)
# Index at chunk_list 304  is  ../../Pelin/Chunks/DBUS/IMP_ROUTEID_CHUNKS/40D_103.csv :  (186244, 25)

# %%
# remove some of the weather data not available in api
for df in chunks:
    df.drop(['wet_bulb_temp(C)', 'vapour_pressure(hPa)'], axis=1, inplace=True)
    
list(chunks[0])
# Out:
# ['TRIPID',
#  'PROGRNUMBER',
#  'STOPPOINTID',
#  'PLANNEDTIME_ARR',
#  'PLANNEDTIME_DEP',
#  'ACTUALTIME_ARR',
#  'ACTUALTIME_DEP',
#  'DIFFERENCETIME_ARR',
#  'DIFFERENCETIME_DEP',
#  'ROUTEID',
#  'ACTUALTIME_ARR_DATETIME',
#  'TOTAL_JOURNEY_TIME',
#  'TIME_OF_DAY',
#  'DAY_OF_WEEK',
#  'TRIPS_TIME_PROPORTION_v2',
#  'DAYOFSERVICE',
#  'PLANNEDTIME_DEP_DATETIME',
#  'PLANNEDTIME_DEP_R_M5',
#  'rain',
#  'temp',
#  'dew_pt_temp(C)',
#  'humidity(%)',
#  'sea_lvl_pressure(hPa)']

# %% [markdown]
# ## 2 Obtaining timetable and proportions for each route's stop sequence

# %%
# want to drop any route dataframes if their r2 was below the acceptance threshold
drop_routes = pd.read_csv('../../Pelin/ML_route_bel_tres_R2_cor01_df.csv')
drop = drop_routes['ROUTEID'].unique()

count = 0
for df in chunks:
    if df['ROUTEID'].unique()[0] in drop:
        chunks.pop(count)
    count += 1

# %%
# confirm that the 6 routes have been dropped 
len(chunks)
# Out:
# 299

# %% [markdown]
# #### Daily timetables obtained for improved query time

# %%
for df in chunks:
    
    try:
        getDayTimetable(df, "Monday")
    except ValueError:
        # value error occurs if that route does not run on the day specified
        pass
    try:
        getDayTimetable(df, "Tuesday")
    except ValueError:
        pass
    try:
        getDayTimetable(df, "Wednesday")
    except ValueError:
        pass
    try:
        getDayTimetable(df, "Thursday")
    except ValueError:
        pass
    try:
        getDayTimetable(df, "Friday")
    except ValueError:
        pass
    
    try:
        getDayTimetable(df, "Saturday")
    except ValueError:
        pass
        
    try:
        getDayTimetable(df, "Sunday")
    except ValueError:
        pass
# Out:
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# ...
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()
# /tmp/ipykernel_10141/2668783288.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   target=(df.groupby(['ROUTEID','DAY_OF_WEEK','STOPPOINTID' , 'PLANNEDTIME_DEP_R_M5'], as_index=False))['TRIPS_TIME_PROPORTION_v2', 'PLANNEDTIME_DEP'].mean()

# %%
dtypes={'STOPPOINTID':'category',
       'PLANNEDTIME_DEP':'int64',
       'ROUTEID':'category',
       'DAY_OF_WEEK':'category',
       'TRIPS_TIME_PROPORTION_v2':'float32',
       'PLANNEDTIME_DEP_R_M5':'category'}

location = '../timetables_V3'
data = [location, dtypes]

# commenting this out as will use yield function instead
#timetable_chunks = getTimetableChunks(data)

# %%
#method to yield(return generator object) dfs for memory efficent concat( to avoid expotential memory use)
#https://stackoverflow.com/questions/70911236/how-can-i-concat-the-huge-pandas-dataframes-into-one
def yield_dfs(x):
